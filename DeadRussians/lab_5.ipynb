# %% [markdown]
# # Виконання

# %% [markdown]
# ### Для початку імпортуємо модулі.

# %%
import requests
import spacy
from lxml.html import fromstring

# %% [markdown]
# *Імпортовані модулі*

# %% [markdown]
# ### Оголосимо назви основних URL.

# %%
base_url = 'https://pestrecy-rt.ru/news/tag/list/specoperaciia'
list_path = '/html/body/main/ul/li'
headline_xpath = 'a/div[1]/h2/text()'
next_page_xpath = '/html/body/main/div[2]/div/a'
next_page_xpath_2 = '/html/body/main/div[2]/div/a[2]'

# %% [markdown]
# *Назви url*

# %% [markdown]
# ### Зіскрапимо всі заголовки.

# %%
headlines = []

def get_next_page_url(soup, is_first):
    try:
        if is_first:
            return soup.xpath(next_page_xpath)[0].get('href')
        else:
            return soup.xpath(next_page_xpath_2)[0].get('href')
    except IndexError:
        return None

def extract_headlines(response_text):
    responsed = fromstring(response_text)
    return [element.xpath(headline_xpath)[0] for element in responsed.xpath(list_path)]

is_first_page = True
while True:
    response = requests.get(base_url)
    headlines.extend(extract_headlines(response.text))
    next_page_url = get_next_page_url(fromstring(response.text), is_first_page)

    if not next_page_url:
        break
    else:
        is_first_page = False
        base_url = next_page_url

# %%
headlines = [headline.strip() for headline in headlines]
headlines
# Out:
# ['Представляем список необходимой гуманитарной помощи для бойцов СВО',
#  'Военный комиссар РТ поздравил военных пенсионеров с профессиональным праздником',
#  '«Надо Родину защищать!»: отец участников СВО гордится своими сыновьями',
#  'В храме деревни Куюки откроют сбор гуманитарной помощи мобилизованным',
#  'Ефрейтор из села Пестрецы рассказал о службе на СВО и планах на будущее',
#  'На участвовавших в СВО татарстанцев и их детей ввели единовременную выплату',
#  'Соцфонд Татарстана рассказал о выплатах участникам СВО и членам их семей',
#  'Жизнью военнослужащего в зоне СВО из села Карповка поделились его родители',
#  'Участники СВО, получившие инвалидность, могут получить страховую выплату до 2,3 млн',
#  'Участвующие в СВО военные пенсионеры будут получать компенсацию пенсий',
#  'Военнослужащие в Татарстане получат льготу при предоставлении земельных участков',
#  'Пестречинцы могут принять участие в сборе гуманитарной помощи военным',
#  'Зарплата участников СВО выросла до 210 тысяч рублей',
#  'Названы топ-3 вещи, необходимые военнослужащему на СВО',
#  'В пестречинском приюте «Шатлык» состоялась встреча с участником СВО',
#  'В Пестрецах объявлен сбор гуманитарной помощи для участников СВО',
#  'Жители села Пановка плетут маскировочные сети для бойцов в зоне СВО',
#  'Глава Пестрецов поздравил маму Героя России Ивана Додосова с днем рождения',
#  'Уроженец Пестречинского района попал в число героев на выставке в Казани',
#  'Участникам СВО из Татарстана выплатят по 305 тыс. рублей',
#  'В Татарстане организована постоянная поддержка военнослужащих СВО и членов их семей',
#  'Участник СВО из села Карповка Пестречинского района рассказал о службе',
#  'Проводили в последний путь участника СВО из Пестречинского района',
#  'Пестречинские бойцы поблагодарили за нужные вещи в зоне СВО',
#  'В Татарстане планируют принять законопроект о предоставлении земли участникам СВО',
#  'В пестречинском детском саду состоялась встреча с участником СВО',
#  '«Он спас своих братьев ценой собственной жизни»: история мобилизованного из Пестречинского района',
#  'Глава Пестречинского района отреагировал на просьбу жены бойца СВО спилить аварийные деревья',
#  'Татарстан разрабатывает меры поддержки с учетом мнения участников СВО',
#  'В Пестречинском районе маскировочные сети плетут в пяти точках',
#  'Пестречинские дети нарисовали рисунки бойцам СВО',
#  'В Татарстане появится чат-бот по мерам поддержки для военнослужащих и их семей',
#  'Мама Героя России Ивана Додосова из Пестрецов рассказала о детстве сына',
#  'Жена бойца СВО Елена Корчагина: «Для молодых бойцов он был как отец»',
#  'Пестречинцы присоединились к марафону «ВСЕ СВОИ»',
#  'В ЖК «Царево» проходит акция в поддержку службы по контракту',
#  'Благодаря поддержке властей в Татарстане смогли трудоустроиться 77 бывших участников СВО',
#  'Выплаты, льготы и специальная ипотека: что гарантирует контракт каждому военнослужащему',
#  'Судебные приставы приостанавливают производство в отношении участников СВО',
#  'Где в Татарстане можно узнать подробности о службе по контракту',
#  'Лейла Фазлеева о бойцах СВО: «Мы гордимся ими, они дают нам возможность жить»',
#  'Жены пестречинских военнослужащих сфотографировались в кителях своих мужей',
#  'Житель Пестречинского района рассказал, почему решил принять участие в СВО',
#  'Российские военные применили в зоне СВО новейшую огнеметную систему «Тосочка»',
#  'Сегодня в Татарстане пройдет первый марафон о контрактной службе «ВСЕ СВОИ»',
#  'Жена погибшего на СВО: «Я была уверена, что он вернется»',
#  'Жительница Татарстана оставила свой бизнес, чтобы отправиться в зону СВО',
#  'Сайт «Герои Татарстана» будет транслировать первый марафон о военной службе по контракту',
#  'В Татарстане в поддержку службы по контракту пройдет марафон «ВСЕ СВОИ»',
#  'Досрочная пенсия, выплаты детям и льготы за ЖКУ: как поддерживают бойцов СВО и их семьи',
#  'Герои России стали гостями профильных смен для детей в Татарстане',
#  'В Царево работает мобильный пункт по отбору на военную службу по контракту',
#  'Соцфонд Татарстана рассказал о мерах поддержки участников СВО и их семей',
#  'Добровольца из Пестрецов наградили медалью «За отвагу»',
#  'Глава Пестречинского района наколол дрова жене служащего на СВО',
#  'В российскую армию за последнее время набрано 38 тысяч добровольцев',
#  'Пестречинцы могут получить от 195 тысяч за службу по контракту',
#  'Соцфонд Татарстана рассказал о повышенном пенсионном стаже за участие в СВО',
#  'Раис РТ отменил пени за просрочку платежей ЖКУ для семей участников СВО',
#  'Участники СВО с семьями отправились в круиз по Волге',
#  'Видеоинтервью с бойцом из Пестречинского района набрало более 150 тыс. просмотров',
#  'Детям участников СВО в Татарстане планируют выплатить по 20 тыс. рублей',
#  'Контрактникам по востребованным специальностям ДОСААФ РТ заплатит 105 тысяч рублей',
#  'Мобилизованный татарстанец женился во время отпуска',
#  'Военная ипотека, страховка и льготы: офицер Росгвардии из РТ о службе по контракту',
#  'Депутат Госдумы и Герой России поздравили с рождением детей семей участников СВО',
#  'Соцфонд напомнил о выплатах бойцам спецоперации и членам их семей',
#  'Герой России из Пестрецов рассказал о том, как выбрал путь военного',
#  'Жителя Пестречинского района посмертно наградили Орденом Мужества',
#  'Семьи Пестречинских мобилизованных пригласили на ледовое шоу',
#  'Пестречинские мобилизованные рассказали о своей службе в зоне СВО',
#  'Путин лично вручил звезду Героя России военнослужащему из Татарстана Расиму Баксикову',
#  'В Пестречинском районе проводится фотоконкурс «Жена Героя-2023»',
#  'Все военнослужащие по контракту в РТ имеют право на получение военной ипотеки',
#  'Жену мобилизованного глава Пестречинского района поздравил сразу с двумя праздниками',
#  'Депутат из Татарстана дал советы, как избежать проблем в случае волны мобилизации',
#  'Пестречинец рассказал о своем военном опыте на передовой',
#  'Семьи военных были приглашены на пестречинский фестиваль «Скорлупино»',
#  'В Татарстане расширены категории участников СВО, имеющих право на бесплатную юрпомощь',
#  'Опубликован список востребованных военно-учетных специальностей для службы по контракту',
#  'Пестречинцев приглашают на военную службу по контракту',
#  'Татарстан расширил выплаты в 2 млн рублей семьям погибших участников спецоперации',
#  'В Татарстане участники СВО бесплатно получат земельные участки',
#  'Дети-сироты участников СВО из Татарстана получат преимущественное право в получении жилья',
#  'В фонде «Защитники Отечества» в Казани расскажут о мерах поддержки участников СВО',
#  'В Пестречинском районе простились с участником СВО Александром Агафоновым',
#  'Минобороны предложило перечень заболеваний, с которыми не возьмут на службу по контракту',
#  'На сайте «Герои Татарстана» можно подать заявку на службу по контракту в рядах ВС РФ',
#  'В Татарстане заработал официальный сайт для будущих контрактников',
#  'В Казани открылся центр по приему на контрактную службу «Батыр»',
#  'ДУМ РТ готовит очередную партию гуманитарного груза в зону спецоперации',
#  'Путин подписал закон о льготах для участников СВО при поступлении в вузы и колледжи',
#  'В пестречинском приюте состоялась встреча с участниками СВО',
#  'Правительство Татарстана передало бойцам «Алга» и «Тимер» боевые дроны',
#  'Участники спецоперации будут поступать в вузы по отдельной квоте',
#  'Участник СВО из Пестречинского района награжден медалью',
#  'В казанских парках заработал прокат велосипедов для детей с ОВЗ',
#  'Пестречинский район в очередной раз отправил гумпомощь военным',
#  'В Пестречинском районе продолжают оказывать помощь мобилизованным и их семьям',
#  'Отделение госфонда «Защитники Отечества» появилось в Пестрецах',
#  'Военнослужащий из Пестречинского района вернулся из зоны СВО',
#  'Ограниченно годным россиянам разрешат заключать контракт с ВС РФ при мобилизации',
#  'В Пестречинском детском садике состоялась встреча с участником СВО',
#  'Участникам СВО из Татарстана передали помощь от Минэкологии РТ',
#  'В Татарстане создают единую базу волонтеров, помогающих бойцам спецоперации',
#  'Пестречинца наградили медалью Жукова',
#  'Татарстанцы получили возможность бесплатно отправлять посылки в зону СВО',
#  'В Пестречинском районе простились с погибшим на СВО Валерием Межва',
#  'Путин подписал указ о призыве находящихся в запасе на военные сборы',
#  'Какие кандидаты востребованы на службе по контракту и как туда попасть',
#  'Военкомат Татарстана ответит на самые главные вопросы о службе по контракту',
#  'Пестречинцы отправили очередной груз в зону СВО',
#  'Пестречинцам напомнили, что срочники могут выбрать военную службу по контракту',
#  'В Татарстане начинающие бизнесмены могут получить 350 тысяч рублей по социальному контракту',
#  'Пестречинская молодежь встретилась с участниками СВО',
#  'Пестречинские студенты встретились с участником СВО',
#  'В селе Кощаково простились с погибшим в ходе специальной военной операции',
#  'Подать заявление на военную службу по контракту можно через Госуслуги',
#  'В военном комиссариате района набирают мужчин на контрактную службу в ВС РФ',
#  'В Кощаково установили баннер в честь погибшего военнослужащего',
#  'В селе Кряш-Серда прошла встреча с мобилизованным, прибывшим в отпуск',
#  'Пестречинский военкомат набирает мужчин на службу по контракту',
#  'Вернувшийся с СВО пестречинец сделал сюрприз племяннице — видео',
#  'Мобилизованные пестречинцы могут получить бесплатную юридическую помощь',
#  'Мобилизованный из Пестречинского района провел семинар по тактической медицине',
#  'Герой России Иван Додосов: «Герой – это защитник своего дома, а мой дом – Татарстан»',
#  'В селе Богородское прошла встреча с мобилизованными',
#  'Пестречинцы могут принять участие в сборе гуманитарной помощи военным',
#  'Мобилизованный учитель из Пестречинского района встретился со своими учениками',
#  'Военнослужащий из Пестречинского района встретился с молодежью',
#  'Какие выплаты положены военнослужащим и их семьям',
#  'Минниханов расширил указ о выплатах семьям погибших участников спецоперации',
#  'Мобилизованные пестречинцы после двухнедельного отпуска вновь уезжают в зону СВО',
#  'Жителям Татарстана рассказали, как можно выбрать воинскую часть',
#  'В каких случаях сдача в плен считается преступлением',
#  'В Пестречинском районе продолжается работа над обращениями от семей военных',
#  'В Пестречинском районе почтили память погибших в зоне СВО',
#  'Пестречинские дети отправили военнослужащим рисунки',
#  'В Татарстане расширены меры поддержки детей участников спецоперации',
#  'ДУМ РТ разрешило исповедующим ислам военным не соблюдать пост в Рамадан',
#  'Семье участника спецоперации из Куюков вручили ноутбук',
#  'Названы льготы, положены семьям погибших военных',
#  'Путин подписал закон об ответственности за дискредитацию участников спецоперации',
#  'К началу учебного года появится новый учебник истории с разделом о спецоперации',
#  'Единороссы и молодогвардейцы посетили семью мобилизованного из Пестрецов',
#  'Госдума приняла закон о наказании за фейки против участников СВО',
#  'В Кощаково собирают соления для отправки мобилизованным ребятам',
#  'Пестречинские «Серебряные волонтёры» отправили более 10 тонн гумпомощи мобилизованным и их семьям',
#  'Священник Виталий Беляев: «Здесь молятся все»',
#  'Пестречинцев просят помочь с плетением маскировочных сетей для участников СВО',
#  'Пенсионерка Тамара Лаптева из села Пестрецы связала для военнослужащих мочалки',
#  'Волонтеры Татарстана помогли собрать более 918 тонн гуманитарной помощи для Донбасса',
#  'Минниханов: Создание Фонда поддержки участников СВО не снимает с нас ответственность',
#  'Пестречинцы собрали для мобилизованных земляков почти 4 млн рублей',
#  'В День защитника отечества в Татарстане пройдет телемарафон в поддержку наших бойцов',
#  'Путин поручил ввести двухнедельный отпуск для участников СВО',
#  'Депутат-доброволец Эдуард Шарафиев примет участие в телемарафоне «Все для Победы!» в Татарстане',
#  'Пестречинское «Чистое сердце» собрало больше тонны гуманитарного груза для мобилизованных',
#  'Путин подписал закон о поддержке вдов погибших военных',
#  'Пестречинцы отправят около миллиона посылок в зону СВО',
#  'Ковалинцы изготовливают маскировочные сети, окопные свечи и вяжут шерстяные носки',
#  'В Татарстане пройдет телемарафон в поддержку участников спецоперации',
#  '«У людей там другие приоритеты, живы – и хорошо»: «Татар-информ» вернулся с Донбасса',
#  'Как можно отправить письмо или посылку военнослужащему в зону спецоперации',
#  'Госдума приняла закон о поддержке супругов погибших военнослужащих',
#  'Мобилизованные пестречинцы на полигоне воинской части обустроили походный храм',
#  'Пестречинцы могут принять участие в сборе гуманитарной помощи военным',
#  'Пользователей соцсетей растрогали кадры возвращения пестречинца из зоны СВО',
#  'В Пестречинском районе готовят к отправке партию маскировочных сетей в зону СВО',
#  'Семьям мобилизованных из Пестречинского района подключили газ и заменили электропроводку',
#  'Татарстанцев приглашают принять участие в акции «Письмо солдату»',
#  'В селе Кощаково делают окопные свечи',
#  'В Пестрецах продолжается сбор «гуманитарки» для мобилизованных',
#  '207 семей мобилизованных Пестречинского района получили продуктовую помощь',
#  'Священник из Куюков доставил мобилизованным землякам гуманитарный груз',
#  'Глава Кряш-Сердинского сельского поселения лично передал гуманитарную помощь военнослужащим',
#  'В Кощаково добровольцы будут изготавливать окопные свечи',
#  'Жители села Кряш-Серда приобрели автомобиль для отправки мобилизованным ребятам',
#  'Минтруд рассказал о мерах поддержки семей мобилизованных татарстанцев',
#  'Пестречинцы отправили гуманитарную помощь для мобилизованных земляков',
#  'Президент Татарстана подарил сыновьям участника СВО «умные» колонки',
#  'В Пестречинском молодежном центре открыт сбор гуманитарной помощи мобилизованным',
#  'Герой России Иван Додосов из Пестрецов рассказал о своем подвиге в зоне СВО',
#  'Студенческие отряды Татарстана изготавливают печи для мобилизованных',
#  'Дети участников СВО из Пестречинского района станут гостями новогоднего представления в театре Тинчурина',
#  'Около 2,5 тыс. детей мобилизованных посетят Республиканскую ёлку',
#  'Дети участников СВО из Пестречинского района поедут на Кремлевскую елку в Казань',
#  'Пестречинцы могут отправить мобилизованным близким письма полевой почтой',
#  'В Татарстане за месяц за бесплатной юрпомощью обратилось более 300 мобилизованных',
#  'Матери мобилизованного из села Янцевары привезли дрова на зиму',
#  'Пестречинцы могут принять участие в сборе гуманитарной помощи военным',
#  'В Пестречинском районе работает штаб по поддержке мобилизованных и их семей',
#  'Пестречинские ансамбли приняли участие на концерте для мобилизованных татарстанцев',
#  'Мамы и жены мобилизованных пестречинцев получили продуктовые подарки',
#  'Мобилизованным татарстанцам передали более 350 сладких пирогов',
#  'Доходы мобилизованных не будут учитывать при назначении детских пособий',
#  'Мобилизованным из села Кощаково привезли гуманитарную помощь',
#  'Мобилизованные через госуслуги смогут пожаловаться на задержки выплат']

# %% [markdown]
# *Назви заголовків*

# %% [markdown]
# ### Відфільтруємо імена мертвих чмобиків.

# %%
from spacy_download import load_spacy
import pandas as pd

core = spacy.load('ru_core_news_sm')
chmobics = set()
for l in headlines:
    chmobics.update([ent.text for ent in core(l).ents if ent.label_ == "PER"])

pd.DataFrame(chmobics, columns=['Chmobics'])
# Out:
#                   Chmobics
# 0               Минниханов
# 1                   Куюков
# 2           Тамара Лаптева
# 3          Елена Корчагина
# 4         Расиму Баксикову
# 5          Эдуард Шарафиев
# 6           Ивана Додосова
# 7                Тинчурина
# 8                   Жукова
# 9           Лейла Фазлеева
# 10  Александром Агафоновым
# 11          Валерием Межва
# 12          Виталий Беляев
# 13                   Путин
# 14            Иван Додосов
# 15                 Соцфонд
# 16               Пестрецов

# %% [markdown]
# *Імена чмобиків*
